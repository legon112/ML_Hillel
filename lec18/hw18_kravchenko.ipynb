# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration

# %%
tokenizer = T5Tokenizer.from_pretrained("google-t5/t5-small")
model = T5ForConditionalGeneration.from_pretrained("google-t5/t5-small")
# Out:
# Loading weights: 100%|██████████| 131/131 [00:00<00:00, 426.55it/s, Materializing param=shared.weight]

# %%
input_ids = tokenizer("translate English to German: I learn ML", return_tensors="pt").input_ids
outputs = model.generate(input_ids)
translation = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(f"Переклад: {translation}")
# Out:
# Переклад: Ich lerne ML

# %%
input_ids = tokenizer("translate English to French: Darth Vader is a sith", return_tensors="pt").input_ids
outputs = model.generate(input_ids)
translation = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(f"Переклад: {translation}")
# Out:
# Переклад: Darth Vader est un sythme

# %%
input_ids = tokenizer("translate English to Romanian: Hello, Denys Stupak!", return_tensors="pt").input_ids
outputs = model.generate(input_ids)
translation = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(f"Переклад: {translation}")
# Out:
# Переклад: Salut, Denys Stupak!
